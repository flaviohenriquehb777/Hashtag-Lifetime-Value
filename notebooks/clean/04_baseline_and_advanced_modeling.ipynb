# %% [markdown]
# # 04 – Baseline & Advanced Modeling
#
# **Fase CRISP-DM:** Modeling
#
# ## Organização da fase
# Para deixar a modelagem mais organizada, esta fase foi separada em dois blocos:
#
# 1. **Seleção inicial com validação cruzada**: notebook `03_model_selection_cross_validation.ipynb`
# 2. **Treinamento final e próximos experimentos**: este notebook e a sequência da fase de avaliação
#
# ### Onde está a comparação dos 4 modelos?
# A comparação entre `DummyRegressor`, `Regressão Linear`, `Regressão Polinomial (grau 2) + Linear` e `Random Forest`, com `KFold=5` e `R²`, foi isolada no notebook:
#
# - `notebooks/clean/03_model_selection_cross_validation.ipynb`
#
# Essa separação evita misturar seleção inicial de modelos com a próxima etapa de treinamento final, avaliação e regras de negócio.
