# %% [markdown]
# # 05 – Model Evaluation & Business Rules
#
# **Fase CRISP-DM:** Evaluation
#
# Nesta etapa comparamos os 4 modelos na base de teste usando a `ltv_base_final.csv`, com as métricas `R2`, `RMSE` e `MAE`. O modelo polinomial é avaliado com `Ridge`, conforme solicitado.

# %%
from pathlib import Path
import sys
import warnings

import pandas as pd
from IPython.display import display

warnings.filterwarnings("ignore")
pd.set_option("display.float_format", lambda value: f"{value:,.4f}")

PROJECT_ROOT = Path.cwd().resolve()
while PROJECT_ROOT != PROJECT_ROOT.parent and not (PROJECT_ROOT / "config" / "config.yaml").exists():
    PROJECT_ROOT = PROJECT_ROOT.parent

sys.path.insert(0, str(PROJECT_ROOT))

from src.models import evaluate_models_on_final_base_test

df_final = pd.read_csv(PROJECT_ROOT / "data" / "final" / "ltv_base_final.csv")
display(df_final.head())

# %% [markdown]
# ## Comparativo no Conjunto de Teste

# %%
test_metrics, split_info = evaluate_models_on_final_base_test(
    df_final,
    random_state=42,
)

print("Tamanho dos conjuntos usados na avaliação:")
display(split_info)

print("Comparativo dos 4 modelos no conjunto de teste:")
display(test_metrics)
